# %%
from mpl_toolkits.mplot3d import Axes3D #For visualization of data
from sklearn.preprocessing import StandardScaler #For algorithms
import matplotlib.pyplot as plt #For plotting graphs
from tkinter import * #For Gui
from tkinter import messagebox #For msg box
from tkinter.messagebox import showinfo #For msg box
import numpy as np #For scientific calculation
import pandas as pd #For data analysis
import os #For working with directory
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Disease Prediction

# %%
train = pd.read_csv("//content/drive/MyDrive/CBIT/DiseasePredictionTrainingDataset.csv")
# train.head()

# %%
DF = pd.read_csv("/content/drive/MyDrive/CBIT/DiseasePredictionTrainingDataset.csv", index_col='prognosis')
#Assuming `DF` is your DataFrame containing the data
hm = DF.sample(n=1)  # Selecting a random row from DF


# Printing the shape of the DataFrame
print(hm.shape)
# Out:
# (1, 132)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [raw]
# Data Pre-processing

# %%
"""train = train.drop(["Unnamed: 133"],axis=1)
train.head()"""
# Out:
# 'train = train.drop(["Unnamed: 133"],axis=1)\ntrain.head()'

# %%
test = pd.read_csv('/content/drive/MyDrive/CBIT/DiseasePredictionTestingDataset.csv')
# Assuming `test` is your DataFrame containing the test data
print('Shape of test data:', test.shape)
# Out:
# Shape of test data: (42, 133)

# %%
from sklearn.model_selection import train_test_split
A = train[["prognosis"]] # diseases
B = train.drop(["prognosis"],axis=1) # symptoms
C = test.drop(["prognosis"],axis=1) # symptoms - testing
x_train, x_test, y_train, y_test = train_test_split(B,A,test_size=0.2) # 20:80

# %%
unique_symptoms = []
for column in A.columns:
    unique_symptoms.extend(A[column].unique())

unique_symptoms = list(set(unique_symptoms))
print(unique_symptoms)
# Out:
# ['Malaria', 'Acne', 'Allergy', 'Urinary tract infection', 'Hyperthyroidism', 'Obesity', 'Dimorphic hemmorhoids(piles)', 'Hypoglycemia', 'Bronchitis', 'Psoriasis', 'Weight loss', 'Impetigo', 'AIDS', 'Typhoid', 'Diabetes', 'Pneumonia', 'Depression', 'ibromyalgia', 'Anxiety', 'Gastroenteritis', 'Bacterial Infection', 'Cervical spondylosis', 'Hypogonadism, Male', 'Osteoarthristis', 'Insomnia', 'Common Cold', '(vertigo) Paroymsal  Positional Vertigo', 'Peptic ulcer diseae', 'Tuberculosis', 'Hepatitis C', 'Juvenile Rheumatoid Arthritis', 'GERD', 'Diarrhea', 'Hyperhidrosis', 'Heart attack', 'Hypertension', 'Bronchial Asthma', 'Hepatitis B', 'Migraine', 'Constipation', 'Hypothyroidism']

# %%
A
# Out:
#                                     prognosis
# 0                                    Insomnia
# 1                                    Insomnia
# 2                                    Insomnia
# 3                                    Insomnia
# 4                                    Insomnia
# ...                                       ...
# 4915  (vertigo) Paroymsal  Positional Vertigo
# 4916                                     Acne
# 4917                  Urinary tract infection
# 4918                                Psoriasis
# 4919                                 Impetigo
#
# [4920 rows x 1 columns]

# %% [markdown]
# # Training the data

# %% [raw]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
mod = RandomForestClassifier(n_estimators = 50,n_jobs = 5, criterion= 'gini',random_state = 42, max_depth = 6)
mod = mod.fit(x_train,y_train.values.ravel())
pred = mod.predict(x_test)
print("Train Accuracy: ", accuracy_score(y_train, mod.predict(x_train)))
print("Test Accuracy: ", accuracy_score(y_test, pred))
# Out:
# Train Accuracy:  0.9933943089430894
# Test Accuracy:  0.9959349593495935

# %%
# Predict using `mod` model and add the results to `test` DataFrame
test["predicted"] = mod.predict(C)

# Compare actual and predicted values and assign "Correct" or "Incorrect" to "result" column
test["result"] = np.where(test["prognosis"] == test["predicted"], "Correct", "Incorrect")

# Keep only "prognosis", "predicted", and "result" columns in `test` DataFrame
test = test[["prognosis", "predicted", "result"]]

test
# Out:
#                                   prognosis  \
# 0                                  Insomnia
# 1                                   Allergy
# 2                                      GERD
# 3                               ibromyalgia
# 4                                Depression
# 5                       Peptic ulcer diseae
# 6                                      AIDS
# 7                                  Diabetes
# 8                           Gastroenteritis
# 9                          Bronchial Asthma
# 10                             Hypertension
# 11                                 Migraine
# 12                     Cervical spondylosis
# 13                                  Anxiety
# 14                                 Diarrhea
# 15                                  Malaria
# 16                       Hypogonadism, Male
# 17                               Bronchitis
# 18                                  Typhoid
# 19                                  Obesity
# 20                              Hepatitis B
# 21                              Hepatitis C
# 22                              Weight loss
# 23                             Constipation
# 24                            Hyperhidrosis
# 25                             Tuberculosis
# 26                              Common Cold
# 27                                Pneumonia
# 28             Dimorphic hemmorhoids(piles)
# 29                             Heart attack
# 30                      Bacterial Infection
# 31                           Hypothyroidism
# 32                          Hyperthyroidism
# 33                             Hypoglycemia
# 34                          Osteoarthristis
# 35            Juvenile Rheumatoid Arthritis
# 36  (vertigo) Paroymsal  Positional Vertigo
# 37                                     Acne
# 38                  Urinary tract infection
# 39                                Psoriasis
# 40                                 Impetigo
# 41                                 Insomnia
#
#                                   predicted     result
# 0                                  Insomnia    Correct
# 1                                   Allergy    Correct
# 2                                      GERD    Correct
# 3                               ibromyalgia    Correct
# 4                                Depression    Correct
# 5                       Peptic ulcer diseae    Correct
# 6                                      AIDS    Correct
# 7                                  Diabetes    Correct
# 8                           Gastroenteritis    Correct
# 9                          Bronchial Asthma    Correct
# 10                             Hypertension    Correct
# 11                                 Migraine    Correct
# 12                     Cervical spondylosis    Correct
# 13                                  Anxiety    Correct
# 14                                 Diarrhea    Correct
# 15                                  Malaria    Correct
# 16                       Hypogonadism, Male    Correct
# 17                               Bronchitis    Correct
# 18                                  Typhoid    Correct
# 19                                  Obesity    Correct
# 20                              Hepatitis B    Correct
# 21                              Hepatitis C    Correct
# 22                              Weight loss    Correct
# 23                             Constipation    Correct
# 24                            Hyperhidrosis    Correct
# 25                             Tuberculosis    Correct
# 26                              Common Cold    Correct
# 27                                Pneumonia    Correct
# 28             Dimorphic hemmorhoids(piles)    Correct
# 29                             Heart attack    Correct
# 30                      Bacterial Infection    Correct
# 31                           Hypothyroidism    Correct
# 32                          Hyperthyroidism    Correct
# 33                             Hypoglycemia    Correct
# 34                          Osteoarthristis    Correct
# 35            Juvenile Rheumatoid Arthritis    Correct
# 36  (vertigo) Paroymsal  Positional Vertigo    Correct
# 37                                     Acne    Correct
# 38                  Urinary tract infection    Correct
# 39                                Psoriasis    Correct
# 40                                 Impetigo    Correct
# 41                                Psoriasis  Incorrect

# %% [raw]
# Decision Tree Classifier

# %%
import pickle

# Assuming `mod` is your trained model
with open('model.pkl', 'wb') as f:
    pickle.dump(mod, f)
